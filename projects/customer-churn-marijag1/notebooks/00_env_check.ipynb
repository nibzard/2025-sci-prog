# %% [markdown]
# # 00 – Environment Check
#
# Ova bilježnica služi za provjeru programskog okruženja u kojem je projekt razvijan.
# Prikazane su verzije korištenih biblioteka te ispravnost osnovnih alata za numeričku analizu i vizualizaciju podataka.
# Time se osigurava da se rezultati projekta mogu reproducirati u istom softverskom okruženju.

# %%
import sys
import numpy as np
import pandas as pd
import sklearn
import matplotlib
import seaborn as sns

print("PYTHON:", sys.version)
print("NUMPY:", np.__version__)
print("PANDAS:", pd.__version__)
print("SKLEARN:", sklearn.__version__)
print("MATPLOTLIB:", matplotlib.__version__)
print("SEABORN:", sns.__version__)
# Out:
# PYTHON: 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]
# NUMPY: 2.0.2
# PANDAS: 2.2.2
# SKLEARN: 1.6.1
# MATPLOTLIB: 3.10.0
# SEABORN: 0.13.2

# %%
import numpy as np

x = np.linspace(0, 10, 100)
y = np.sin(x)

import matplotlib.pyplot as plt
plt.plot(x, y)
plt.title("Test plot")
plt.show()
